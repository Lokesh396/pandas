# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# 5               6                     I am a developer by profession       No
# 6               7                     I am a developer by profession      Yes
# 7               8                     I am a developer by profession      Yes
# 8               9                     I am a developer by profession       No
# 9              10                     I am a developer by profession      Yes
# 10             11                     I am a developer by profession      Yes
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
pd.set_option('display.max_columns',61)
pd.set_option('display.max_rows',61)

# %%
schema_df=pd.read_csv('survey_results_schema.csv',index_col='Column')

# %%
schema_df.head()
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?
# Age         What is your age (in years)? If you prefer not...
# Age1stCode  At what age did you write your first line of c...

# %%
schema_df.tail()
# Out:
#                                                          QuestionText
# Column
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...

# %%
print('video 2')
# Out:
# video 2

# %%
df.head(1)
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           1  I am a developer by profession      Yes  NaN         13
#
#   CompFreq  CompTotal  ConvertedComp  Country   CurrencyDesc CurrencySymbol  \
# 0  Monthly        NaN            NaN  Germany  European Euro            EUR
#
#   DatabaseDesireNextYear                         DatabaseWorkedWith  \
# 0   Microsoft SQL Server  Elasticsearch;Microsoft SQL Server;Oracle
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
#
#                       Ethnicity Gender  \
# 0  White or of European descent    Man
#
#                                           JobFactors              JobSat  \
# ...

# %%
schema_df.head(3)
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?

# %%
df.shape
# Out:
# (64461, 61)

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
schema_df.columns
# Out:
# Index(['QuestionText'], dtype='object')

# %%
df.loc[:,'Hobbyist':'Country']
# Out:
#       Hobbyist   Age            Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0          Yes   NaN                    13  Monthly        NaN            NaN
# 1           No   NaN                    19      NaN        NaN            NaN
# 2          Yes   NaN                    15      NaN        NaN            NaN
# 3          Yes  25.0                    18      NaN        NaN            NaN
# 4          Yes  31.0                    16      NaN        NaN            NaN
# 5           No   NaN                    14      NaN        NaN            NaN
# 6          Yes   NaN                    18  Monthly        NaN            NaN
# 7          Yes  36.0                    12   Yearly   116000.0       116000.0
# 8           No  30.0                    20      NaN        NaN            NaN
# 9          Yes  22.0                    14   Yearly    25000.0        32315.0
# 10         Yes  23.0                    13   Yearly    31000.0        40070.0
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df.set_index('Respondent',inplace=True)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
df.loc[[1,2]]
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
schema_df.loc['Ethnicity','QuestionText']
# Out:
# 'Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.'

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
filt =df['LanguageWorkedWith'].str.contains('Python',na=False)

# %%
df.loc[filt,'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
# 17                   C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 22                                             Java;Python
# 26                                       JavaScript;Python
# 27             Bash/Shell/PowerShell;C;C++;Java;Python;SQL
# 28                                                Python;R
# 29                                  C#;C++;HTML/CSS;Python
# 30       Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 32                               C;C++;Java;Python;SQL;VBA
# 36             C#;Go;HTML/CSS;Java;JavaScript;Python;R;SQL
# 38                    HTML/CSS;JavaScript;Python;Ruby;Rust
# 39                                               C#;Python
# ...

# %%
filt.value_counts()
# Out:
# False    39174
# True     25287
# Name: LanguageWorkedWith, dtype: int64

# %%
df.rename(columns={'ConvertedComp':'SalaryUsd'},inplace=True)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...

# %%
df['SalaryUsd']
# Out:
# Respondent
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8         116000.0
# 9              NaN
# 10         32315.0
# 11         40070.0
# 12         14268.0
# 13         38916.0
# 14         66000.0
# 15             NaN
# 16        108576.0
# 17         79000.0
# 18       1260000.0
# 19         83400.0
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24         91883.0
# 25             NaN
# 26         71093.0
# 27             NaN
# 28             NaN
# 29             NaN
# 30         38778.0
#            ...
# 61121          NaN
# 61490          NaN
# 61561          NaN
# 61570          NaN
# 61907          NaN
# 61918          NaN
# 61983          NaN
# 62391          NaN
# 62464          NaN
# 62605          NaN
# 62834          NaN
# 62954          NaN
# 63077          NaN
# 63396          NaN
# 63452          NaN
# 63640          NaN
# ...

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
# 6         No
# 7        Yes
# 8        Yes
# 9         No
# 10       Yes
# 11       Yes
# 12        No
# 13       Yes
# 14       Yes
# 15       Yes
# 16       Yes
# 17       Yes
# 18       Yes
# 19        No
# 20       Yes
# 21       Yes
# 22       Yes
# 23       Yes
# 24       Yes
# 25        No
# 26        No
# 27       Yes
# 28       Yes
# 29       Yes
# 30       Yes
#         ...
# 61121    Yes
# 61490    Yes
# 61561    Yes
# 61570     No
# 61907    Yes
# 61918    Yes
# 61983    Yes
# 62391    Yes
# 62464    Yes
# 62605     No
# 62834    Yes
# 62954    Yes
# 63077    Yes
# 63396    Yes
# 63452    Yes
# 63640    Yes
# 63796    Yes
# 63820    Yes
# 63994    Yes
# 64013    Yes
# 64104    Yes
# 64236    Yes
# 64330    Yes
# 64480    Yes
# 64567    Yes
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df["Hobbyist"]=df["Hobbyist"].map({'Yes':True,'No':False})

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession     True   NaN
# 2                              I am a developer by profession    False   NaN
# 3                                 I code primarily as a hobby     True   NaN
# 4                              I am a developer by profession     True  25.0
# 5           I used to be a developer by profession, but no...     True  31.0
# 6                              I am a developer by profession    False   NaN
# 7                              I am a developer by profession     True   NaN
# 8                              I am a developer by profession     True  36.0
# 9                              I am a developer by profession    False  30.0
# 10                             I am a developer by profession     True  22.0
# 11                             I am a developer by profession     True  23.0
# ...

# %%
df['Country'].sort_values()
# Out:
# Respondent
# 8631     Afghanistan
# 25001    Afghanistan
# 58171    Afghanistan
# 42668    Afghanistan
# 51509    Afghanistan
# 37951    Afghanistan
# 28374    Afghanistan
# 7616     Afghanistan
# 43966    Afghanistan
# 62698    Afghanistan
# 51532    Afghanistan
# 36574    Afghanistan
# 43946    Afghanistan
# 65381    Afghanistan
# 38672    Afghanistan
# 35753    Afghanistan
# 43808    Afghanistan
# 37159    Afghanistan
# 44555    Afghanistan
# 35687    Afghanistan
# 37605    Afghanistan
# 44556    Afghanistan
# 23798    Afghanistan
# 42188    Afghanistan
# 65456    Afghanistan
# 44697    Afghanistan
# 60507    Afghanistan
# 898      Afghanistan
# 51900    Afghanistan
# 35179    Afghanistan
#             ...
# 34827            NaN
# 35643            NaN
# 36113            NaN
# 36448            NaN
# 40550            NaN
# 41922            NaN
# 42026            NaN
# 42825            NaN
# 43177            NaN
# 44670            NaN
# 44891            NaN
# 46810            NaN
# ...

# %%
df.sort_values(by=['Country','SalaryUsd'],ascending=[True,False],inplace=True)

# %%
df.sort_index()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession     True   NaN
# 2                              I am a developer by profession    False   NaN
# 3                                 I code primarily as a hobby     True   NaN
# 4                              I am a developer by profession     True  25.0
# 5           I used to be a developer by profession, but no...     True  31.0
# 6                              I am a developer by profession    False   NaN
# 7                              I am a developer by profession     True   NaN
# 8                              I am a developer by profession     True  36.0
# 9                              I am a developer by profession    False  30.0
# 10                             I am a developer by profession     True  22.0
# 11                             I am a developer by profession     True  23.0
# ...

# %%
df[['Country','SalaryUsd']].head(50)
# Out:
#                 Country  SalaryUsd
# Respondent
# 62788       Afghanistan  1000000.0
# 65381       Afghanistan  1000000.0
# 65456       Afghanistan  1000000.0
# 38672       Afghanistan   231192.0
# 28374       Afghanistan   130000.0
# 9839        Afghanistan    23328.0
# 63848       Afghanistan    23328.0
# 51862       Afghanistan    20950.0
# 51509       Afghanistan    20220.0
# 44484       Afghanistan    18660.0
# 15422       Afghanistan    18000.0
# 2932        Afghanistan    16335.0
# 26540       Afghanistan    13992.0
# 57269       Afghanistan    10884.0
# 26775       Afghanistan     8016.0
# 30568       Afghanistan     5448.0
# 30522       Afghanistan     4668.0
# 28811       Afghanistan     4509.0
# 34969       Afghanistan     4356.0
# 26857       Afghanistan     2328.0
# 33878       Afghanistan     1860.0
# 35753       Afghanistan      780.0
# 18049       Afghanistan      109.0
# 35295       Afghanistan        0.0
# 898         Afghanistan        NaN
# ...

# %%
df['SalaryUsd'].nlargest(10)
# Out:
# Respondent
# 5725     2000000.0
# 54263    2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 123      2000000.0
# 125      2000000.0
# 193      2000000.0
# 665      2000000.0
# 699      2000000.0
# Name: SalaryUsd, dtype: float64

# %%
df.nlargest(10,'SalaryUsd')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5725                           I am a developer by profession    False  26.0
# 54263                          I am a developer by profession     True  29.0
# 43430                          I am a developer by profession     True  33.0
# 59279                          I am a developer by profession     True   NaN
# 46711                          I am a developer by profession     True   NaN
# 123                            I am a developer by profession     True  26.0
# 125         I am not primarily a developer, but I write co...     True  41.0
# 193                            I am a developer by profession     True  29.0
# 665                            I am a developer by profession     True  24.0
# 699         I am not primarily a developer, but I write co...     True  39.0
#
#                       Age1stCode CompFreq     CompTotal  SalaryUsd  \
# Respondent
# ...

# %%
df.nsmallest(10,'SalaryUsd')
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 35295       I am a developer by profession     True   NaN         13  Monthly
# 47357       I am a developer by profession     True   NaN          5   Weekly
# 6054        I am a developer by profession     True  38.0         15   Yearly
# 27135       I am a developer by profession    False   NaN         16   Yearly
# 60292       I am a developer by profession     True   NaN         12   Yearly
# 38813       I am a developer by profession    False   NaN         18  Monthly
# 8470        I am a developer by profession     True   NaN          5  Monthly
# 41006       I am a developer by profession     True  22.0         17   Yearly
# 15493       I am a developer by profession    False  44.0         17  Monthly
# 57369       I am a developer by profession    False  44.0         18  Monthly
#
#             CompTotal  SalaryUsd      Country        CurrencyDesc  \
# Respondent
# ...

# %%
df.sort_values(by='Country',inplace=True)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 62788                          I am a developer by profession     True   NaN
# 44697                          I am a developer by profession     True   NaN
# 44556                          I am a developer by profession    False   NaN
# 44555                          I am a developer by profession    False   NaN
# 43966                  I am a student who is learning to code     True  25.0
# 43946                  I am a student who is learning to code     True   NaN
# 43808                          I am a developer by profession     True   NaN
# 42668                          I am a developer by profession     True   NaN
# 42188                  I am a student who is learning to code     True   NaN
# 40349                          I am a developer by profession     True   NaN
# 39582                          I am a developer by profession    False   NaN
# ...

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
filt=df['LanguageWorkedWith'].str.contains('Python',na=False)

# %%
filt.value_counts()
# Out:
# False    39174
# True     25287
# Name: LanguageWorkedWith, dtype: int64

# %%
filt=df['YearsCode']>='10'

# %%
filt.value_counts()
# Out:
# True     56782
# False     7679
# Name: YearsCode, dtype: int64

# %%
df.head()
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 62788               I am a developer by profession     True   NaN        NaN
# 44697               I am a developer by profession     True   NaN        NaN
# 44556               I am a developer by profession    False   NaN         17
# 44555               I am a developer by profession    False   NaN         20
# 43966       I am a student who is learning to code     True  25.0         13
#
#            CompFreq  CompTotal  SalaryUsd      Country    CurrencyDesc  \
# Respondent
# 62788        Weekly  8000000.0  1000000.0  Afghanistan    Albanian lek
# 44697           NaN        NaN        NaN  Afghanistan             NaN
# 44556           NaN        NaN        NaN  Afghanistan  Afghan afghani
# 44555           NaN        NaN        NaN  Afghanistan             NaN
# 43966           NaN        NaN        NaN  Afghanistan             NaN
#
# ...

# %%
df=pd.read_csv("/home/lokesh/Documents/data/survey_results_public.csv")
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# ...

# %%
df['ConvertedComp'].head(10)
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7    116000.0
# 8         NaN
# 9     32315.0
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Respondent       32231.0
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.describe()
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df['ConvertedComp'].count()
# Out:
# 34756

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
schema_df.columns
# Out:
# Index(['QuestionText'], dtype='object')

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
schema_df.loc['MainBranch']
# Out:
# QuestionText    Which of the following options best describes ...
# Name: MainBranch, dtype: object

# %%
df['Hobbyist'].value_counts(normalize=True)
# Out:
# Yes    0.782228
# No     0.217772
# Name: Hobbyist, dtype: float64

# %%
df=pd.read_csv("/home/lokesh/Documents/data/survey_results_public2018.csv")
df
# Out:
# /home/lokesh/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Respondent Hobby OpenSource                       Country  \
# 0               1   Yes         No                         Kenya
# 1               3   Yes        Yes                United Kingdom
# 2               4   Yes        Yes                 United States
# 3               5    No         No                 United States
# 4               7   Yes         No                  South Africa
# 5               8   Yes         No                United Kingdom
# ...

# %%
df.loc['SocialMedia']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3/dist-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1505                 if not ax.contains(key):
# -> 1506                     error()
#    1507             except TypeError as e:
#
# /usr/lib/python3/dist-packages/pandas/core/indexing.py in error()
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#
# KeyError: 'the label [SocialMedia] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-99f90645d072> in <module>
# ----> 1 df.loc['SocialMedia']
#
# /usr/lib/python3/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1371
# ...

# %%
df.shape
# Out:
# (98855, 129)

# %%
df.columns
# Out:
# Index(['Respondent', 'Hobby', 'OpenSource', 'Country', 'Student', 'Employment',
#        'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType',
#        ...
#        'Exercise', 'Gender', 'SexualOrientation', 'EducationParents',
#        'RaceEthnicity', 'Age', 'Dependents', 'MilitaryUS', 'SurveyTooLong',
#        'SurveyEasy'],
#       dtype='object', length=129)

# %%
df=pd.read_csv('/home/lokesh/Documents/data/developer_survey_2019/survey_results_public.csv')

# %%
df.head(1)
# Out:
#    Respondent                              MainBranch Hobbyist OpenSourcer  \
# 0           1  I am a student who is learning to code      Yes       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel UndergradMajor  \
# 0  Primary/elementary school            NaN
#
#                                             EduOther OrgSize DevType  \
# 0  Taught yourself a new language, framework, or ...     NaN     NaN
#
#   YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney  \
# 0         4         10          NaN       NaN    NaN      NaN      NaN
#
#   MgrWant JobSeek LastHireDate LastInt FizzBuzz JobFactors ResumeUpdate  \
# 0     NaN     NaN          NaN     NaN      NaN        NaN          NaN
#
# ...

# %%
df['SocialMedia']
# Out:
# 0                         Twitter
# 1                       Instagram
# 2                          Reddit
# 3                          Reddit
# 4                        Facebook
# 5                         YouTube
# 6                         YouTube
# 7                         YouTube
# 8                         Twitter
# 9                         YouTube
# 10                            NaN
# 11                         Reddit
# 12                        Twitter
# 13                         Reddit
# 14                        YouTube
# 15                        YouTube
# 16                        YouTube
# 17                  VK ВКонта́кте
# 18                       WhatsApp
# 19                       Facebook
# 20       I don't use social media
# 21                      Instagram
# 22                         Reddit
# 23                         Reddit
# 24                        YouTube
# 25       I don't use social media
# 26                        YouTube
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df['Country'].value_counts()
# Out:
# United States                            20949
# India                                     9061
# Germany                                   5866
# United Kingdom                            5737
# Canada                                    3395
# France                                    2391
# Brazil                                    1948
# Poland                                    1922
# Australia                                 1903
# Netherlands                               1852
# Russian Federation                        1694
# Spain                                     1604
# Italy                                     1576
# Sweden                                    1274
# Switzerland                                978
# Israel                                     952
# Turkey                                     949
# Pakistan                                   923
# Ukraine                                    868
# Austria                                    839
# ...

# %%
country_group=df.groupby(['Country'])

# %%
country_group.get_group('India')
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# 67             68          I am a developer by profession      Yes
# 74             75          I am a developer by profession      Yes
# 77             78          I am a developer by profession       No
# 82             83          I am a developer by profession      Yes
# 88             89  I am a student who is learning to code      Yes
# 89             90          I am a developer by profession      Yes
# 98             99  I am a student who is learning to code      Yes
# 103           104          I am a developer by profession      Yes
# ...

# %%
filt= df['Country']=='India'
df.loc[filt,'SocialMedia'].value_counts()
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# WeChat 微信                      5
# Hello                          5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts(normalize=True).loc['India']
# Out:
# SocialMedia
# WhatsApp                    0.342379
# YouTube                     0.208405
# LinkedIn                    0.109355
# Facebook                    0.096301
# Instagram                   0.094126
# Twitter                     0.062063
# Reddit                      0.054162
# I don't use social media    0.028627
# Snapchat                    0.002634
# Hello                       0.000573
# WeChat 微信                   0.000573
# VK ВКонта́кте               0.000458
# Youku Tudou 优酷              0.000229
# Weibo 新浪微博                  0.000115
# Name: SocialMedia, dtype: float64

# %%
country_group['ConvertedComp'].median().loc["India"]
# Out:
# 10080.0

# %%
country_group['ConvertedComp'].agg(['median','mean']).loc['India']
# Out:
# median    10080.000000
# mean      28057.664916
# Name: India, dtype: float64

# %%
filt= df['Country']=='India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').value_counts(normalize=True)).loc['India']
# Out:
# False    0.648915
# True     0.351085
# Name: LanguageWorkedWith, dtype: float64

# %%
country_respondents=df['Country'].value_counts()

# %%
country_uses_python=country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_uses_python
# Out:
# Country
# Afghanistan                                      8
# Albania                                         23
# Algeria                                         40
# Andorra                                          0
# Angola                                           2
# Antigua and Barbuda                              0
# Argentina                                      191
# Armenia                                         28
# Australia                                      790
# Austria                                        338
# Azerbaijan                                      17
# Bahamas                                          2
# Bahrain                                          4
# Bangladesh                                     204
# Barbados                                         1
# Belarus                                         69
# Belgium                                        296
# Belize                                           1
# ...

# %%
python_df=pd.concat([country_respondents,country_uses_python], axis='columns')

# %%
python_df
# Out:
#                                            Country  LanguageWorkedWith
# Afghanistan                                     44                   8
# Albania                                         86                  23
# Algeria                                        134                  40
# Andorra                                          7                   0
# Angola                                           5                   2
# Antigua and Barbuda                              9                   0
# Argentina                                      553                 191
# Armenia                                         86                  28
# Australia                                     1903                 790
# Austria                                        839                 338
# Azerbaijan                                      49                  17
# Bahamas                                          3                   2
# ...

# %% [raw]
# python_df.rename(columns={'Country':'Respondents','LanguageWorkedWith':'NumknowsPython'},inplace=True)

# %%
python_df.rename(columns={'Country':'Respondents','LanguageWorkedWith':'NumknowsPython'},inplace=True)

# %%
python_df
# Out:
#                                            Respondents  NumknowsPython
# Afghanistan                                         44               8
# Albania                                             86              23
# Algeria                                            134              40
# Andorra                                              7               0
# Angola                                               5               2
# Antigua and Barbuda                                  9               0
# Argentina                                          553             191
# Armenia                                             86              28
# Australia                                         1903             790
# Austria                                            839             338
# Azerbaijan                                          49              17
# Bahamas                                              3               2
# ...

# %%
python_df['pctKnowspython']=(python_df['NumknowsPython']/python_df['Respondents'])*100

# %%
python_df
# Out:
#                                            Respondents  NumknowsPython  \
# Afghanistan                                         44               8
# Albania                                             86              23
# Algeria                                            134              40
# Andorra                                              7               0
# Angola                                               5               2
# Antigua and Barbuda                                  9               0
# Argentina                                          553             191
# Armenia                                             86              28
# Australia                                         1903             790
# Austria                                            839             338
# Azerbaijan                                          49              17
# Bahamas                                              3               2
# ...

# %%
python_df.sort_values('pctKnowspython',ascending=False,inplace=True)

# %%
python_df
# Out:
#                                            Respondents  NumknowsPython  \
# Dominica                                             1               1
# Niger                                                1               1
# Timor-Leste                                          1               1
# Sao Tome and Principe                                1               1
# Turkmenistan                                         7               6
# Mauritania                                           7               5
# Bahamas                                              3               2
# Guinea                                               3               2
# Guyana                                               3               2
# Uganda                                              72              47
# Iceland                                             49              30
# Namibia                                              5               3
# ...

# %%
python_df.loc['India']
# Out:
# Respondents       9061.000000
# NumknowsPython    3105.000000
# pctKnowspython      34.267741
# Name: India, dtype: float64

# %%
import pandas as pd

# %%
na_vals=['NA','Missing']
df=pd.read_csv("/home/lokesh/Documents/data/developer_survey_2019/survey_results_public.csv",na_values=na_vals)

# %%
df.head(1)
# Out:
#    Respondent                              MainBranch Hobbyist OpenSourcer  \
# 0           1  I am a student who is learning to code      Yes       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel UndergradMajor  \
# 0  Primary/elementary school            NaN
#
#                                             EduOther OrgSize DevType  \
# 0  Taught yourself a new language, framework, or ...     NaN     NaN
#
#   YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney  \
# 0         4         10          NaN       NaN    NaN      NaN      NaN
#
#   MgrWant JobSeek LastHireDate LastInt FizzBuzz JobFactors ResumeUpdate  \
# 0     NaN     NaN          NaN     NaN      NaN        NaN          NaN
#
# ...

# %%
df['YearsCode'].head(3)
# Out:
# 0      4
# 1    NaN
# 2      3
# Name: YearsCode, dtype: object

# %%
df['YearsCode']=df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-c75b77d4e281> in <module>
# ----> 1 df['YearsCode']=df['YearsCode'].astype(float)
#
# /usr/lib/python3/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ...

# %%
df["YearsCode"].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df["YearsCode"].replace('Less than 1 year',0,inplace=True)

# %%
df["YearsCode"].replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
df['YearsCode']=df['YearsCode'].astype(float)

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].count()
# Out:
# 87938

# %%
df.shape
# Out:
# (88883, 85)
