# %%
import pandas as pd

# %%
df=pd.read_csv('survey_results_public.csv',index_col='Respondent')

# %%
df.head(2)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol     ...                       SurveyEase  \
# Respondent                    ...
# 1                     EUR     ...       Neither easy nor difficult
# 2                     GBP     ...                              NaN
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# ...

# %%
filt=df['Country']=='India'

# %%
india_df=df.loc[filt]

# %%
india_df.head(1)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 7           I am a developer by profession      Yes  NaN         18  Monthly
#
#             CompTotal  ConvertedComp Country          CurrencyDesc  \
# Respondent
# 7                 NaN            NaN   India  United States dollar
#
#            CurrencySymbol     ...      SurveyEase SurveyLength Trans  \
# Respondent                    ...
# 7                     USD     ...             NaN          NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 7           Computer science, computer engineering, or sof...
#
#            WebframeDesireNextYear WebframeWorkedWith  \
# Respondent
# 7                             NaN                NaN
#
#                                     WelcomeChange WorkWeekHrs YearsCode  \
# Respondent
# 7           A lot more welcome now than last year         NaN         6
#
#            YearsCodePro
# Respondent
# ...

# %%
india_df.to_csv('modified.csv')

# %%
india_df.to_csv('modified.tsv',sep='\t')

# %%
india_df.to_excel('modified.xlsx')

# %%
ind_df=pd.read_excel('modified.xlsx')

# %%
ind_df.head(1)
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           7  I am a developer by profession      Yes  NaN         18
#
#   CompFreq CompTotal  ConvertedComp Country          CurrencyDesc  \
# 0  Monthly                      NaN   India  United States dollar
#
#       ...      SurveyEase SurveyLength Trans  \
# 0     ...             NaN          NaN   NaN
#
#                                       UndergradMajor WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...                    NaN
#
#   WebframeWorkedWith                          WelcomeChange WorkWeekHrs  \
# 0                NaN  A lot more welcome now than last year         NaN
#
#   YearsCode YearsCodePro
# 0         6            4
#
# [1 rows x 61 columns]

# %%
india_df.to_json('modified.json',orient='records',lines=True)

# %%
df_json=pd.read_json('modified.json',orient='records',lines=True)

# %%
df_json
# Out:
#        Age Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# 0      NaN         18  Monthly         NaN            NaN   India
# 1      NaN         18  Monthly         NaN            NaN   India
# 2      NaN         22     None         NaN            NaN   India
# 3     21.0         17     None         NaN            NaN   India
# 4     36.0         31   Yearly  21000000.0       293196.0   India
# 5      NaN         18  Monthly         NaN            NaN   India
# 6     24.0         19   Yearly    840000.0        11728.0   India
# 7     20.0         12     None         NaN            NaN   India
# 8     22.0         16     None         NaN            NaN   India
# 9      NaN         27     None         NaN            NaN   India
# 10    26.0         17     None         NaN            NaN   India
# 11     NaN         14  Monthly    900000.0       150792.0   India
# 12    24.0         18  Monthly     25000.0         4188.0   India
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine=create_engine('postgresql://lokesh:admin@localhost:33227/practice_database')

# %%
india_df.to_sql('sample_table',engine)

# %%
india_df.to_sql('sample_table',engine)
